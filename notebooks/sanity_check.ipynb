# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
import numpy as np
import pandas as pd

# %%
import json

# %%
sys.path.append('../src/')

# %%
from workflow.data_utils import load_csv

# %% [markdown]
# ### Constants and Functions

# %%
JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %% [markdown]
# ### Loads

# %%
train_df = load_csv('../data/train.csv',
                     nrows=10000,
                     converters={column: json.loads for column in JSON_COLUMNS})

# %%
display_all(train_df.loc[199:209])
# Out:
#     channelGrouping      date  \
# 199        Referral  20160902
# 200        Referral  20160902
# 201  Organic Search  20160902
# 202  Organic Search  20160902
# 203        Referral  20160902
# 204      Affiliates  20160902
# 205      Affiliates  20160902
# 206        Referral  20160902
# 207      Affiliates  20160902
# 208  Organic Search  20160902
# 209  Organic Search  20160902
#
#                                                 device        fullVisitorId  \
# 199  {'browser': 'Chrome', 'browserVersion': 'not a...  2628175916794749307
# 200  {'browser': 'Firefox', 'browserVersion': 'not ...  4235514069735400633
# 201  {'browser': 'Safari', 'browserVersion': 'not a...  1350700416054916432
# 202  {'browser': 'Chrome', 'browserVersion': 'not a...  7470776509190254697
# 203  {'browser': 'Chrome', 'browserVersion': 'not a...  3585871094003849779
# 204  {'browser': 'Chrome', 'browserVersion': 'not a...  2903318777294784357
# 205  {'browser': 'Safari', 'browserVersion': 'not a...  8094671042653767256
# 206  {'browser': 'Chrome', 'browserVersion': 'not a...  0780206376162514125
# 207  {'browser': 'Chrome', 'browserVersion': 'not a...  2309547610315337293
# 208  {'browser': 'Chrome', 'browserVersion': 'not a...  5337857247476555852
# 209  {'browser': 'Chrome', 'browserVersion': 'not a...  2855105319365658799
#
#                                             geoNetwork  \
# 199  {'continent': 'Americas', 'subContinent': 'Nor...
# 200  {'continent': 'Asia', 'subContinent': 'Souther...
# 201  {'continent': 'Americas', 'subContinent': 'Nor...
# 202  {'continent': 'Europe', 'subContinent': 'Easte...
# 203  {'continent': 'Americas', 'subContinent': 'Sou...
# 204  {'continent': 'Europe', 'subContinent': 'Easte...
# 205  {'continent': 'Oceania', 'subContinent': 'Aust...
# 206  {'continent': 'Americas', 'subContinent': 'Nor...
# 207  {'continent': 'Asia', 'subContinent': 'Souther...
# 208  {'continent': 'Americas', 'subContinent': 'Nor...
# 209  {'continent': 'Americas', 'subContinent': 'Nor...
#
#                           sessionId  socialEngagementType  \
# 199  2628175916794749307_1472853878  Not Socially Engaged
# 200  4235514069735400633_1472882056  Not Socially Engaged
# 201  1350700416054916432_1472879649  Not Socially Engaged
# 202  7470776509190254697_1472836646  Not Socially Engaged
# 203  3585871094003849779_1472857403  Not Socially Engaged
# 204  2903318777294784357_1472826827  Not Socially Engaged
# 205  8094671042653767256_1472807005  Not Socially Engaged
# 206  0780206376162514125_1472850326  Not Socially Engaged
# 207  2309547610315337293_1472824833  Not Socially Engaged
# 208  5337857247476555852_1472838046  Not Socially Engaged
# 209  2855105319365658799_1472868546  Not Socially Engaged
#
#                                                 totals  \
# 199  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 200  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 201  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 202  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 203  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 204  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 205  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 206  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 207  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 208  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 209  {'visits': '1', 'hits': '1', 'pageviews': '1',...
#
#                                          trafficSource     visitId  \
# 199  {'referralPath': '/_/scs/mail-static/_/js/k=gm...  1472853878
# 200  {'referralPath': '/analytics/web/inpage_launch...  1472882056
# 201  {'campaign': '(not set)', 'source': 'google', ...  1472879649
# 202  {'campaign': '(not set)', 'source': 'google', ...  1472836646
# 203  {'referralPath': '/analytics/web/inpage_launch...  1472857403
# 204  {'campaign': 'Data Share Promo', 'source': 'Pa...  1472826827
# 205  {'campaign': 'Data Share Promo', 'source': 'Pa...  1472807005
# 206  {'referralPath': '/', 'campaign': '(not set)',...  1472850326
# 207  {'campaign': 'Data Share Promo', 'source': 'Pa...  1472824833
# 208  {'campaign': '(not set)', 'source': 'google', ...  1472838046
# 209  {'campaign': '(not set)', 'source': 'google', ...  1472868546
#
#      visitNumber  visitStartTime
# 199            7      1472853878
# 200            1      1472882056
# 201            2      1472879649
# 202            1      1472836646
# 203            1      1472857403
# 204            1      1472826827
# 205            1      1472807005
# 206            2      1472850326
# 207            1      1472824833
# 208            1      1472838046
# 209            1      1472868546

# %%
test_df = load_csv('../data/test.csv',
                     nrows=10000,
                     converters={column: json.loads for column in JSON_COLUMNS})

# %%
display_all(test_df.loc[100:120])
# Out:
#     channelGrouping      date  \
# 100     Paid Search  20171016
# 101  Organic Search  20171016
# 102  Organic Search  20171016
# 103  Organic Search  20171016
# 104  Organic Search  20171016
# 105  Organic Search  20171016
# 106  Organic Search  20171016
# 107  Organic Search  20171016
# 108  Organic Search  20171016
# 109  Organic Search  20171016
# 110  Organic Search  20171016
# 111  Organic Search  20171016
# 112  Organic Search  20171016
# 113     Paid Search  20171016
# 114  Organic Search  20171016
# 115  Organic Search  20171016
# 116     Paid Search  20171016
# 117  Organic Search  20171016
# 118  Organic Search  20171016
# 119     Paid Search  20171016
# 120          Direct  20171016
#
#                                                 device        fullVisitorId  \
# 100  {'browser': 'Chrome', 'browserVersion': 'not a...  3471893362789140384
# 101  {'browser': 'Safari', 'browserVersion': 'not a...  5528891136690135588
# 102  {'browser': 'Internet Explorer', 'browserVersi...  6405559856055284021
# 103  {'browser': 'Chrome', 'browserVersion': 'not a...  9543478172051431577
# 104  {'browser': 'Chrome', 'browserVersion': 'not a...  3514137592642751920
# 105  {'browser': 'Chrome', 'browserVersion': 'not a...  8807649912132227978
# 106  {'browser': 'Chrome', 'browserVersion': 'not a...  2255827507265790585
# 107  {'browser': 'Internet Explorer', 'browserVersi...  2120129608233101123
# 108  {'browser': 'Chrome', 'browserVersion': 'not a...    71006190734202407
# 109  {'browser': 'Chrome', 'browserVersion': 'not a...  3080174699214658801
# 110  {'browser': 'Safari', 'browserVersion': 'not a...  2641875785381223638
# 111  {'browser': 'Chrome', 'browserVersion': 'not a...  3677897653314763609
# 112  {'browser': 'Chrome', 'browserVersion': 'not a...  9297020550023167505
# 113  {'browser': 'Safari', 'browserVersion': 'not a...  1195247274638601626
# 114  {'browser': 'Chrome', 'browserVersion': 'not a...  2644926738314674387
# 115  {'browser': 'Safari', 'browserVersion': 'not a...  8607543102716694378
# 116  {'browser': 'Chrome', 'browserVersion': 'not a...   807521800142652388
# 117  {'browser': 'Chrome', 'browserVersion': 'not a...   458589706270254332
# 118  {'browser': 'Chrome', 'browserVersion': 'not a...  4291568253495154853
# 119  {'browser': 'Safari', 'browserVersion': 'not a...  5175344914227052668
# 120  {'browser': 'Chrome', 'browserVersion': 'not a...  3075357509967625405
#
#                                             geoNetwork  \
# 100  {'continent': 'Americas', 'subContinent': 'Nor...
# 101  {'continent': 'Americas', 'subContinent': 'Nor...
# 102  {'continent': 'Americas', 'subContinent': 'Nor...
# 103  {'continent': 'Asia', 'subContinent': 'Souther...
# 104  {'continent': 'Americas', 'subContinent': 'Nor...
# 105  {'continent': 'Americas', 'subContinent': 'Nor...
# 106  {'continent': 'Americas', 'subContinent': 'Nor...
# 107  {'continent': 'Americas', 'subContinent': 'Cen...
# 108  {'continent': 'Americas', 'subContinent': 'Sou...
# 109  {'continent': 'Americas', 'subContinent': 'Nor...
# 110  {'continent': 'Americas', 'subContinent': 'Nor...
# 111  {'continent': 'Americas', 'subContinent': 'Nor...
# 112  {'continent': 'Americas', 'subContinent': 'Nor...
# 113  {'continent': 'Americas', 'subContinent': 'Nor...
# 114  {'continent': 'Europe', 'subContinent': 'North...
# 115  {'continent': 'Americas', 'subContinent': 'Nor...
# 116  {'continent': 'Americas', 'subContinent': 'Nor...
# 117  {'continent': 'Americas', 'subContinent': 'Nor...
# 118  {'continent': 'Americas', 'subContinent': 'Nor...
# 119  {'continent': 'Americas', 'subContinent': 'Nor...
# 120  {'continent': 'Asia', 'subContinent': 'Southea...
#
#                           sessionId  socialEngagementType  \
# 100  3471893362789140384_1508210302  Not Socially Engaged
# 101  5528891136690135588_1508198121  Not Socially Engaged
# 102  6405559856055284021_1508167267  Not Socially Engaged
# 103  9543478172051431577_1508216748  Not Socially Engaged
# 104  3514137592642751920_1508205889  Not Socially Engaged
# 105  8807649912132227978_1508219574  Not Socially Engaged
# 106  2255827507265790585_1508182681  Not Socially Engaged
# 107  2120129608233101123_1508177261  Not Socially Engaged
# 108    71006190734202407_1508178897  Not Socially Engaged
# 109  3080174699214658801_1508168281  Not Socially Engaged
# 110  2641875785381223638_1508207635  Not Socially Engaged
# 111  3677897653314763609_1508169557  Not Socially Engaged
# 112  9297020550023167505_1508187121  Not Socially Engaged
# 113  1195247274638601626_1508172900  Not Socially Engaged
# 114  2644926738314674387_1508146480  Not Socially Engaged
# 115  8607543102716694378_1508206147  Not Socially Engaged
# 116   807521800142652388_1508164252  Not Socially Engaged
# 117   458589706270254332_1508181756  Not Socially Engaged
# 118  4291568253495154853_1508200707  Not Socially Engaged
# 119  5175344914227052668_1508205077  Not Socially Engaged
# 120  3075357509967625405_1508218031  Not Socially Engaged
#
#                                                 totals  \
# 100  {'visits': '1', 'hits': '7', 'pageviews': '6',...
# 101  {'visits': '1', 'hits': '7', 'pageviews': '7',...
# 102  {'visits': '1', 'hits': '7', 'pageviews': '7',...
# 103  {'visits': '1', 'hits': '7', 'pageviews': '5',...
# 104  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 105     {'visits': '1', 'hits': '8', 'pageviews': '8'}
# 106  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 107  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 108  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 109  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 110  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 111     {'visits': '1', 'hits': '8', 'pageviews': '6'}
# 112     {'visits': '1', 'hits': '8', 'pageviews': '6'}
# 113     {'visits': '1', 'hits': '8', 'pageviews': '7'}
# 114  {'visits': '1', 'hits': '9', 'pageviews': '9',...
# 115  {'visits': '1', 'hits': '9', 'pageviews': '9',...
# 116  {'visits': '1', 'hits': '9', 'pageviews': '8',...
# 117  {'visits': '1', 'hits': '9', 'pageviews': '7',...
# 118     {'visits': '1', 'hits': '9', 'pageviews': '6'}
# 119  {'visits': '1', 'hits': '9', 'pageviews': '7',...
# 120  {'visits': '1', 'hits': '9', 'pageviews': '9',...
#
#                                          trafficSource     visitId  \
# 100  {'campaign': 'AW - Dynamic Search Ads Whole Si...  1508210302
# 101  {'campaign': '(not set)', 'source': 'google', ...  1508198121
# 102  {'campaign': '(not set)', 'source': 'google', ...  1508167267
# 103  {'campaign': '(not set)', 'source': 'google', ...  1508216748
# 104  {'campaign': '(not set)', 'source': 'google', ...  1508205889
# 105  {'campaign': '(not set)', 'source': 'google', ...  1508219574
# 106  {'campaign': '(not set)', 'source': 'google', ...  1508182681
# 107  {'campaign': '(not set)', 'source': 'bing', 'm...  1508177261
# 108  {'campaign': '(not set)', 'source': 'google', ...  1508178897
# 109  {'campaign': '(not set)', 'source': 'google', ...  1508168281
# 110  {'campaign': '(not set)', 'source': 'google', ...  1508207635
# 111  {'campaign': '(not set)', 'source': 'google', ...  1508169557
# 112  {'campaign': '(not set)', 'source': 'google', ...  1508187121
# 113  {'campaign': 'AW - Dynamic Search Ads Whole Si...  1508172900
# 114  {'campaign': '(not set)', 'source': 'google', ...  1508146480
# 115  {'campaign': '(not set)', 'source': 'google', ...  1508206147
# 116  {'campaign': 'AW - Dynamic Search Ads Whole Si...  1508164252
# 117  {'campaign': '(not set)', 'source': 'google', ...  1508181756
# 118  {'campaign': '(not set)', 'source': 'google', ...  1508200707
# 119  {'campaign': 'AW - Dynamic Search Ads Whole Si...  1508205077
# 120  {'campaign': '(not set)', 'source': '(direct)'...  1508218031
#
#      visitNumber  visitStartTime
# 100            1      1508210302
# 101            1      1508198121
# 102            1      1508167267
# 103            1      1508216748
# 104            1      1508205889
# 105            2      1508219574
# 106            1      1508182681
# 107            1      1508177261
# 108            1      1508178897
# 109            1      1508168281
# 110            1      1508207635
# 111            4      1508169557
# 112            2      1508187121
# 113            4      1508172900
# 114            1      1508146480
# 115            1      1508206147
# 116            1      1508164252
# 117            1      1508181756
# 118           18      1508200707
# 119            1      1508205077
# 120            1      1508218031

# %%
flat_train_df = load_csv('../data/processed_data/train.csv', nrows=10000)

# %%
display_all(flat_train_df.head())
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime device_browser             device_browserSize  \
# 0            1      1472830385         Chrome  not available in demo dataset
# 1            1      1472880147        Firefox  not available in demo dataset
# 2            1      1472865386         Chrome  not available in demo dataset
# 3            1      1472881213     UC Browser  not available in demo dataset
# 4            2      1472822600         Chrome  not available in demo dataset
#
#            device_browserVersion device_deviceCategory  \
# 0  not available in demo dataset               desktop
# 1  not available in demo dataset               desktop
# 2  not available in demo dataset               desktop
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset                mobile
#
#              device_flashVersion  device_isMobile  \
# 0  not available in demo dataset            False
# 1  not available in demo dataset            False
# 2  not available in demo dataset            False
# 3  not available in demo dataset            False
# 4  not available in demo dataset             True
#
#                  device_language    device_mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device_mobileDeviceInfo device_mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device_mobileDeviceModel     device_mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device_operatingSystem  device_operatingSystemVersion  \
# 0                Windows  not available in demo dataset
# 1              Macintosh  not available in demo dataset
# 2                Windows  not available in demo dataset
# 3                  Linux  not available in demo dataset
# 4                Android  not available in demo dataset
#
#              device_screenColors        device_screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork_city              geoNetwork_cityId  \
# 0                          Izmir  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2                         Madrid  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   geoNetwork_continent geoNetwork_country            geoNetwork_latitude  \
# 0                 Asia             Turkey  not available in demo dataset
# 1              Oceania          Australia  not available in demo dataset
# 2               Europe              Spain  not available in demo dataset
# 3                 Asia          Indonesia  not available in demo dataset
# 4               Europe     United Kingdom  not available in demo dataset
#
#             geoNetwork_longitude               geoNetwork_metro  \
# 0  not available in demo dataset                      (not set)
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset                      (not set)
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   geoNetwork_networkDomain     geoNetwork_networkLocation  \
# 0             ttnet.com.tr  not available in demo dataset
# 1              dodo.net.au  not available in demo dataset
# 2          unknown.unknown  not available in demo dataset
# 3          unknown.unknown  not available in demo dataset
# 4          unknown.unknown  not available in demo dataset
#
#                geoNetwork_region geoNetwork_subContinent  totals_bounces  \
# 0                          Izmir            Western Asia             1.0
# 1  not available in demo dataset             Australasia             1.0
# 2            Community of Madrid         Southern Europe             1.0
# 3  not available in demo dataset          Southeast Asia             1.0
# 4  not available in demo dataset         Northern Europe             1.0
#
#    totals_hits  totals_newVisits  totals_pageviews  totals_transactionRevenue  \
# 0            1               1.0                 1                        NaN
# 1            1               1.0                 1                        NaN
# 2            1               1.0                 1                        NaN
# 3            1               1.0                 1                        NaN
# 4            1               NaN                 1                        NaN
#
#    totals_visits trafficSource_adContent  \
# 0              1                     NaN
# 1              1                     NaN
# 2              1                     NaN
# 3              1                     NaN
# 4              1                     NaN
#
#   trafficSource_adwordsClickInfo.adNetworkType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   trafficSource_adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource_adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource_adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    trafficSource_adwordsClickInfo.page trafficSource_adwordsClickInfo.slot  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#   trafficSource_campaign  trafficSource_campaignCode  \
# 0              (not set)                         NaN
# 1              (not set)                         NaN
# 2              (not set)                         NaN
# 3              (not set)                         NaN
# 4              (not set)                         NaN
#
#   trafficSource_isTrueDirect trafficSource_keyword trafficSource_medium  \
# 0                        NaN        (not provided)              organic
# 1                        NaN        (not provided)              organic
# 2                        NaN        (not provided)              organic
# 3                        NaN       google + online              organic
# 4                       True        (not provided)              organic
#
#   trafficSource_referralPath trafficSource_source
# 0                        NaN               google
# 1                        NaN               google
# 2                        NaN               google
# 3                        NaN               google
# 4                        NaN               google

# %%
common_tr_cols = set(train_df.columns).intersection(flat_train_df.columns)

# %%
for col in common_tr_cols:
    print(col)
    print(set(train_df[col] == flat_train_df[col]))
# Out:
# sessionId
# {True}
# fullVisitorId
# {True}
# channelGrouping
# {True}
# visitNumber
# {True}
# socialEngagementType
# {True}
# visitStartTime
# {True}
# visitId
# {True}
# date
# {True}

# %%
flat_test_df = load_csv('../data/processed_data/test.csv', nrows=10000)

# %%
common_te_cols = set(test_df.columns).intersection(flat_test_df.columns)

# %%
for col in common_te_cols:
    print(col)
    print(set(test_df[col] == flat_test_df[col]))
# Out:
# sessionId
# {True}
# fullVisitorId
# {True}
# channelGrouping
# {True}
# visitNumber
# {True}
# socialEngagementType
# {True}
# visitStartTime
# {True}
# visitId
# {True}
# date
# {True}

# %%
proc_train_df = load_csv('../data/processed_data/processed_train.csv', nrows=10000)

# %%
common_tr_cols = set(proc_train_df.columns).intersection(flat_train_df.columns)

# %%
for col in common_tr_cols:
    print(col)
    print(flat_train_df[col].dtype, proc_train_df[col].dtype)
    print(set(proc_train_df[col] == flat_train_df[col]))
# Out:
# geoNetwork_country
# object object
# {True}
# geoNetwork_continent
# object object
# {True}
# geoNetwork_city
# object object
# {True}
# trafficSource_adwordsClickInfo.page
# float64 float64
# {False, True}
# trafficSource_isTrueDirect
# object object
# {False, True}
# geoNetwork_networkDomain
# object object
# {True}
# date
# int64 int64
# {True}
# trafficSource_adwordsClickInfo.slot
# object object
# {False, True}
# trafficSource_adwordsClickInfo.gclId
# object object
# {False, True}
# trafficSource_adwordsClickInfo.adNetworkType
# object object
# {False, True}
# trafficSource_campaign
# object object
# {True}
# totals_bounces
# float64 float64
# {False, True}
# visitNumber
# int64 int64
# {True}
# device_browser
# object object
# {True}
# device_isMobile
# bool bool
# {True}
# fullVisitorId
# object object
# {True}
# geoNetwork_metro
# object object
# {True}
# totals_pageviews
# int64 float64
# {True}
# trafficSource_referralPath
# object object
# {False, True}
# totals_hits
# int64 int64
# {True}
# trafficSource_medium
# object object
# {True}
# trafficSource_keyword
# object object
# {False, True}
# trafficSource_adContent
# object object
# {False, True}
# geoNetwork_subContinent
# object object
# {True}
# totals_newVisits
# float64 float64
# {False, True}
# sessionId
# object object
# {True}
# channelGrouping
# object object
# {True}
# trafficSource_source
# object object
# {True}
# visitStartTime
# int64 int64
# {True}
# totals_transactionRevenue
# float64 float64
# {False, True}
# visitId
# int64 int64
# {True}
# trafficSource_adwordsClickInfo.isVideoAd
# object object
# {False, True}
# device_operatingSystem
# object object
# {True}
# geoNetwork_region
# object object
# {True}
# device_deviceCategory
# object object
# {True}

# %%
proc_train_df[proc_train_df['totals_transactionRevenue'] == flat_train_df['totals_transactionRevenue']].loc[:, 'totals_transactionRevenue']
# Out:
# 752      37860000.0
# 753     306670000.0
# 799      68030000.0
# 802      26250000.0
# 859     574150000.0
# 866       8380000.0
# 893     395730000.0
# 910      24080000.0
# 922      35480000.0
# 925      35080000.0
# 930      81500000.0
# 942     546320000.0
# 971      63840000.0
# 974     117340000.0
# 976      43710000.0
# 999      34480000.0
# 1000     35390000.0
# 1008    339030000.0
# 1020     33670000.0
# 1022    635500000.0
# 1026    103240000.0
# 1027    305470000.0
# 1037      5150000.0
# 1041     90850000.0
# 1054     10590000.0
# 1055     25680000.0
# 1056    338970000.0
# 2774    593910000.0
# 3161     44790000.0
# 3268     30390000.0
#            ...
# 6695     16790000.0
# 6699      6990000.0
# 6713    113520000.0
# 6716      7480000.0
# 6722     13290000.0
# 6730    300350000.0
# 6741     33980000.0
# 6742     79990000.0
# 6745     74590000.0
# 6748     57580000.0
# 6755     33580000.0
# 6757     13590000.0
# 6761      9980000.0
# 6767     31490000.0
# 6770     21020000.0
# 6771    335310000.0
# 6775     10990000.0
# 6777    111160000.0
# 6782    173880000.0
# 8185     16990000.0
# 8188     19990000.0
# 8192      7990000.0
# 8196     42970000.0
# 8210      1990000.0
# 8223     15190000.0
# 8224     31930000.0
# 8229    244040000.0
# 8231     17590000.0
# 8245    139650000.0
# 8252     37960000.0
# Name: totals_transactionRevenue, Length: 91, dtype: float64

# %% [markdown]
# All match (Nan can't be == to Nan) !!!
